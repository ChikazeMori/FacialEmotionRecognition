# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/CW_Folder_ChikazeMori_200038013"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/CW_Folder_ChikazeMori_200038013

# %%
import sys
import os

py_file_location = "/content/drive/MyDrive/CW_Folder_ChikazeMori_200038013/Code"
sys.path.append(os.path.abspath(py_file_location))

# %%
import Code.CNN as cnn
import Code.basic_models as bm
import os

# %%
import pickle
# %cd "/content/drive/MyDrive/CW_Folder_ChikazeMori_200038013/Code"
for fd in ['SIFT','ORB','HOG']:
  for c in ['SVM','KNN','MLP']:
    print(fd,c)
    results = pickle.load(open(fd+'_'+c+'_result.p','rb'))
    #print(results['speed'])
    print(results['result'])
# Out:
# /content/drive/MyDrive/CW_Folder_ChikazeMori_200038013/Code
# SIFT SVM
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator SVC from version 0.24.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator GridSearchCV from version 0.24.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator KNeighborsClassifier from version 0.24.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# ...

# %%
for model in [ 'ResNet18']:
  for rep in [5, 20]:
    # %cd "/content/drive/MyDrive/CW_Folder_ChikazeMori_200038013/Code"
    print('\n')
    print(model,rep)
    cnn.test(model, rep)
    print('\n\n')
# Out:
# /content/drive/MyDrive/CW_Folder_ChikazeMori_200038013/Code
#
#
# ResNet18 5
# Accuracy of the network on the testset: 74 %
# Accuracy of     1 : 65 %
# Accuracy of     2 : 25 %
# Accuracy of     3 : 25 %
# Accuracy of     4 : 90 %
# Accuracy of     5 : 57 %
# Accuracy of     6 : 51 %
# Accuracy of     7 : 85 %
# 7
# recall [0.66, 0.26, 0.25, 0.9, 0.57, 0.51, 0.86]
# precision [0.83, 0.73, 0.46, 0.86, 0.68, 0.69, 0.63]
# f1 [0.73, 0.38, 0.32, 0.88, 0.62, 0.59, 0.72]
#
#
#
# /content/drive/MyDrive/CW_Folder_ChikazeMori_200038013/Code
#
#
# ResNet18 20
# Accuracy of the network on the testset: 72 %
# Accuracy of     1 : 76 %
# Accuracy of     2 : 29 %
# Accuracy of     3 : 25 %
# Accuracy of     4 : 88 %
# Accuracy of     5 : 58 %
# Accuracy of     6 : 64 %
# Accuracy of     7 : 71 %
# 7
# recall [0.77, 0.3, 0.25, 0.89, 0.59, 0.64, 0.71]
# precision [0.75, 0.71, 0.33, 0.86, 0.61, 0.57, 0.68]
# f1 [0.76, 0.42, 0.28, 0.87, 0.6, 0.61, 0.69]

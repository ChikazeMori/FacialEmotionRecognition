# %%
# mount drive
print('Mounting google drive...')
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/CW_Folder_ChikazeMori_200038013"
# Out:
# Mounting google drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/CW_Folder_ChikazeMori_200038013

# %%
# import functions
from Code.EmotionRecognition import EmotionRecognition
from Code.EmotionRecognitionVideo import EmotionRecognitionVideo

# %%
# test EmotionRecognition

# You can change model_type to any combination of feature descriptors and classifiers listed below:

# Feature descriptors: SIFT, HOG, ORB
# Classifiers: KNN, MLP, SVM

# Simply combine the names with an underscore (feature descriptor comes first, e.g. SIFT_MLP)
# the files referred for this function are stored in Code folder

path_to_testset = 'CW_Dataset/test/'
feature_descriptor = 'HOG'
classifier = 'SVM'
model_type = feature_descriptor + '_' + classifier

# %%
EmotionRecognition(path_to_testset, model_type)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator SVC from version 0.24.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator GridSearchCV from version 0.24.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
# test EmotionRecognitionVideo

# the function takes a path to the video file you want to analyse in Video folder and a CNN model saved in Models folder

path_to_testset = 'test_video.mp4'
model_name = 'ResNet18_5'

# %%
# This code takes some time to run. You can skip it and just load the saved video by running the code below
EmotionRecognitionVideo(path_to_testset,model_name)

# %%
# Compress the video to display on Colab
from IPython.display import HTML
from base64 import b64encode
import os
# Input video path
save_path = 'Video/' + model_name + '.mp4'
# Compressed video path
compressed_path = 'Video/' + model_name + '_compressed.mp4'
# compress the video
os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")
# Show the video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=640 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
